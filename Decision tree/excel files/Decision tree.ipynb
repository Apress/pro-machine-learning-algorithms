# %%
import pandas as pd
data=pd.read_csv('D:/Pro ML book/Decision tree/dt_continuous_dep_indep.csv')

# %%
data.head()
# Out:
#    variable  response
# 0 -0.375348      1590
# 1 -0.374069      2309
# 2 -0.373409       815
# 3 -0.373158      2229
# 4 -0.372627       839

# %%
data.describe()
# Out:
#        variable     response
# count  7.000000     7.000000
# mean  -0.373369  1724.714286
# std    0.001046   661.404242
# min   -0.375348   815.000000
# 25%   -0.373739  1214.500000
# 50%   -0.373158  1996.000000
# 75%   -0.372560  2262.000000
# max   -0.372479  2309.000000

# %%
X=data.drop(['response'],axis=1)
y=data['response']

# %%
from sklearn.tree import DecisionTreeRegressor
depth_tree = DecisionTreeRegressor()

# %%
depth_tree.fit(X, y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#            splitter='best')

# %%
from IPython.display import Image  
from sklearn.externals.six import StringIO  
from sklearn.tree import export_graphviz
import pydot 

features = list(data.columns[1:])

import os
os.environ["PATH"] += os.pathsep + 'C:/Program Files (x86)/Graphviz2.38/bin/'
dot_data = StringIO()  
export_graphviz(depth_tree, out_file=dot_data,feature_names=features,filled=True,rounded=True)

graph = pydot.graph_from_dot_data(dot_data.getvalue())  
Image(graph[0].create_png())
